# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV,KFold,cross_val_score
from sklearn.ensemble import GradientBoostingRegressor

# %%
models = pd.DataFrame({'Models':['Linear Model','Ridge','Lasso','Xgbregressor','RandomForestRegressor','AdaboostRegressor','GradientBoostRegressor',
                                'StackingRegressor'],'RMSE':[50.32,50.32,50.31,39.68,42.53,41.38,40.403,44.39],
                       'RSq':[87.09,87.10,87.18,92.06,90.87,91.35,91.77,90.39],
                       'Adj.RSq' : [87.08,87.09,87.17,92.05,90.85,91.34,91.76,90.37]})

# %%
models
# Out:
#                    Models    RMSE    RSq  Adj.RSq
# 0            Linear Model  50.320  87.09    87.08
# 1                   Ridge  50.320  87.10    87.09
# 2                   Lasso  50.310  87.18    87.17
# 3            Xgbregressor  39.680  92.06    92.05
# 4   RandomForestRegressor  42.530  90.87    90.85
# 5       AdaboostRegressor  41.380  91.35    91.34
# 6  GradientBoostRegressor  40.403  91.77    91.76
# 7       StackingRegressor  44.390  90.39    90.37

# %%
sns.set_theme(style = 'darkgrid')

# %%
plt.figure(figsize = (12,7))
sns.lineplot(x= models['Models'],y = models['RMSE'])
plt.xticks(ticks=range(0,8),labels = models['Models'],rotation = 90)
# Out:
# ([<matplotlib.axis.XTick at 0x27ffb3aa430>,
# ...
#  [Text(0, 0, 'Linear Model'),
#   Text(1, 0, 'Ridge'),
#   Text(2, 0, 'Lasso'),
#   Text(3, 0, 'Xgbregressor'),
#   Text(4, 0, 'RandomForestRegressor'),
#   Text(5, 0, 'AdaboostRegressor'),
#   Text(6, 0, 'GradientBoostRegressor'),
#   Text(7, 0, 'StackingRegressor')])

# %%
plt.figure(figsize = (12,7))
sns.lineplot(x= models['Models'],y = models['RSq'],markers=True, dashes=False)
plt.xticks(ticks=range(0,8),labels = models['Models'],rotation = 90)
# Out:
# ([<matplotlib.axis.XTick at 0x27ffbe55f40>,
# ...
#  [Text(0, 0, 'Linear Model'),
#   Text(1, 0, 'Ridge'),
#   Text(2, 0, 'Lasso'),
#   Text(3, 0, 'Xgbregressor'),
#   Text(4, 0, 'RandomForestRegressor'),
#   Text(5, 0, 'AdaboostRegressor'),
#   Text(6, 0, 'GradientBoostRegressor'),
#   Text(7, 0, 'StackingRegressor')])
